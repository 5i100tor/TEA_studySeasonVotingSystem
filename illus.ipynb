# %% [markdown]
# **Imports**

# %%
import sys
import pandas as pd
sys.path.append('..')
from mechanisms.illus import votesIntoWeightedVotes_converter, barChart_generator, scatterPlot_generator, whatsYourWeight_ID

# %% [markdown]
# **Read in your csv files**

# %%
voting_weights_data_csv = "../data/voting_weight_test_csv_files/0_unweighted_control.csv" # change this to add your own weights csv file and start immediately!
TEA_NFT_data_csv = "../data/nft_data_may_28_2024_cleaned.csv"

# %% [markdown]
# **Add the path where you want your illustrations stored**
#
# e.g. saveToLocation = './basic-voting-calc/illus_results/test_exp/nft_plot.png'

# %%
saveToLocation = './basic-voting-calc/illus_results/test_exp/nft_plot.png' #modify if needed

# %% [markdown]
# Run histogram illustration script:

# %%
output = votesIntoWeightedVotes_converter(TEA_NFT_data_csv, voting_weights_data_csv)
student_nftWeight = output[0]
barChart_generator(student_nftWeight)
# Out:
# mean = 2.4812680115273773
# median_value = 2.0
# max_value  = 9
# min_value = 1

# %% [markdown]
# Run scatter plot illustration script:

# %%
output = votesIntoWeightedVotes_converter(TEA_NFT_data_csv, voting_weights_data_csv)
student_nftWeight = output[0]
scatterPlot_generator(TEA_NFT_data_csv, student_nftWeight)

# %% [markdown]
# **Want to know what your voting power is?**

# %%
yourAddressOrWeight = #'Enter your address here' #0xfcbc07905fee2d64025461b8ddb27f77f256827f

df_TEA_NFT_data = pd.read_csv(TEA_NFT_data_csv)
whatsYourWeight_ID(student_nftWeight, df_TEA_NFT_data, yourAddressOrWeight)
# Out:
#   Cell In[45], line 1
#     yourAddressOrWeight = #'Enter your address here' #0xfcbc07905fee2d64025461b8ddb27f77f256827f
#                           ^
# SyntaxError: invalid syntax
